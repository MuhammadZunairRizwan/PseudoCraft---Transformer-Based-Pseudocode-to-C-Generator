# %%
pip install torch==2.0.1 torchtext==0.15.2
# Out:
# Collecting torch==2.0.1
#   Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchtext==0.15.2
#   Downloading torchtext-0.15.2-cp311-cp311-manylinux1_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.17.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1)
#   Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext==0.15.2) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext==0.15.2) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext==0.15.2) (1.26.4)
# Collecting torchdata==0.6.1 (from torchtext==0.15.2)
#   Downloading torchdata-0.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (0.45.1)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.11/dist-packages (from torchdata==0.6.1->torchtext==0.15.2) (2.3.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.4)
# Collecting lit (from triton==2.0.0->torch==2.0.1)
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.15.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.15.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.15.2) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.3 MB/s eta 0:00:00
# Downloading torchtext-0.15.2-cp311-cp311-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 48.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 76.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 72.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 43.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 6.5 MB/s eta 0:00:00
# Downloading torchdata-0.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 73.3 MB/s eta 0:00:00
# Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 10.0 MB/s eta 0:00:00
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: lit, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchdata, torchtext
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.20.1+cu124 requires torch==2.5.1, but you have torch 2.0.1 which is incompatible.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.0.1 which is incompatible.
# Successfully installed lit-18.1.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 torchdata-0.6.1 torchtext-0.15.2 triton-2.0.0

# %%
# !pip install streamlit pandas torch torchtext pyngrok --quiet

# %% [markdown]
# # **`Transformer From Scratch`**

# %%
import torch
import torch.nn as nn
import math

class LayerNormalization(nn.Module):

    def __init__(self, features: int, eps:float=10**-6) -> None:
        super().__init__()
        self.eps = eps
        self.alpha = nn.Parameter(torch.ones(features)) # alpha is a learnable parameter
        self.bias = nn.Parameter(torch.zeros(features)) # bias is a learnable parameter

    def forward(self, x):
        # x: (batch, seq_len, hidden_size)
         # Keep the dimension for broadcasting
        mean = x.mean(dim = -1, keepdim = True) # (batch, seq_len, 1)
        # Keep the dimension for broadcasting
        std = x.std(dim = -1, keepdim = True) # (batch, seq_len, 1)
        # eps is to prevent dividing by zero or when std is very small
        return self.alpha * (x - mean) / (std + self.eps) + self.bias

class FeedForwardBlock(nn.Module):

    def __init__(self, d_model: int, d_ff: int, dropout: float) -> None:
        super().__init__()
        self.linear_1 = nn.Linear(d_model, d_ff) # w1 and b1
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(d_ff, d_model) # w2 and b2

    def forward(self, x):
        # (batch, seq_len, d_model) --> (batch, seq_len, d_ff) --> (batch, seq_len, d_model)
        return self.linear_2(self.dropout(torch.relu(self.linear_1(x))))

class InputEmbeddings(nn.Module):

    def __init__(self, d_model: int, vocab_size: int) -> None:
        super().__init__()
        self.d_model = d_model
        self.vocab_size = vocab_size
        self.embedding = nn.Embedding(vocab_size, d_model)

    def forward(self, x):
        # (batch, seq_len) --> (batch, seq_len, d_model)
        # Multiply by sqrt(d_model) to scale the embeddings according to the paper
        return self.embedding(x) * math.sqrt(self.d_model)

class PositionalEncoding(nn.Module):

    def __init__(self, d_model: int, seq_len: int, dropout: float) -> None:
        super().__init__()
        self.d_model = d_model
        self.seq_len = seq_len
        self.dropout = nn.Dropout(dropout)
        # Create a matrix of shape (seq_len, d_model)
        pe = torch.zeros(seq_len, d_model)
        # Create a vector of shape (seq_len)
        position = torch.arange(0, seq_len, dtype=torch.float).unsqueeze(1) # (seq_len, 1)
        # Create a vector of shape (d_model)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)) # (d_model / 2)
        # Apply sine to even indices
        pe[:, 0::2] = torch.sin(position * div_term) # sin(position * (10000 ** (2i / d_model))
        # Apply cosine to odd indices
        pe[:, 1::2] = torch.cos(position * div_term) # cos(position * (10000 ** (2i / d_model))
        # Add a batch dimension to the positional encoding
        pe = pe.unsqueeze(0) # (1, seq_len, d_model)
        # Register the positional encoding as a buffer
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + (self.pe[:, :x.shape[1], :]).requires_grad_(False) # (batch, seq_len, d_model)
        return self.dropout(x)

class ResidualConnection(nn.Module):

        def __init__(self, features: int, dropout: float) -> None:
            super().__init__()
            self.dropout = nn.Dropout(dropout)
            self.norm = LayerNormalization(features)

        def forward(self, x, sublayer):
            return x + self.dropout(sublayer(self.norm(x)))

class MultiHeadAttentionBlock(nn.Module):

    def __init__(self, d_model: int, h: int, dropout: float) -> None:
        super().__init__()
        self.d_model = d_model # Embedding vector size
        self.h = h # Number of heads
        # Make sure d_model is divisible by h
        assert d_model % h == 0, "d_model is not divisible by h"

        self.d_k = d_model // h # Dimension of vector seen by each head
        self.w_q = nn.Linear(d_model, d_model, bias=False) # Wq
        self.w_k = nn.Linear(d_model, d_model, bias=False) # Wk
        self.w_v = nn.Linear(d_model, d_model, bias=False) # Wv
        self.w_o = nn.Linear(d_model, d_model, bias=False) # Wo
        self.dropout = nn.Dropout(dropout)

    @staticmethod
    def attention(query, key, value, mask, dropout: nn.Dropout):
        d_k = query.shape[-1]
        # Just apply the formula from the paper
        # (batch, h, seq_len, d_k) --> (batch, h, seq_len, seq_len)
        attention_scores = (query @ key.transpose(-2, -1)) / math.sqrt(d_k)
        if mask is not None:
            # Write a very low value (indicating -inf) to the positions where mask == 0
            attention_scores.masked_fill_(mask == 0, -1e9)
        attention_scores = attention_scores.softmax(dim=-1) # (batch, h, seq_len, seq_len) # Apply softmax
        if dropout is not None:
            attention_scores = dropout(attention_scores)
        # (batch, h, seq_len, seq_len) --> (batch, h, seq_len, d_k)
        # return attention scores which can be used for visualization
        return (attention_scores @ value), attention_scores

    def forward(self, q, k, v, mask):
        query = self.w_q(q) # (batch, seq_len, d_model) --> (batch, seq_len, d_model)
        key = self.w_k(k) # (batch, seq_len, d_model) --> (batch, seq_len, d_model)
        value = self.w_v(v) # (batch, seq_len, d_model) --> (batch, seq_len, d_model)

        # (batch, seq_len, d_model) --> (batch, seq_len, h, d_k) --> (batch, h, seq_len, d_k)
        query = query.view(query.shape[0], query.shape[1], self.h, self.d_k).transpose(1, 2)
        key = key.view(key.shape[0], key.shape[1], self.h, self.d_k).transpose(1, 2)
        value = value.view(value.shape[0], value.shape[1], self.h, self.d_k).transpose(1, 2)

        # Calculate attention
        x, self.attention_scores = MultiHeadAttentionBlock.attention(query, key, value, mask, self.dropout)

        # Combine all the heads together
        # (batch, h, seq_len, d_k) --> (batch, seq_len, h, d_k) --> (batch, seq_len, d_model)
        x = x.transpose(1, 2).contiguous().view(x.shape[0], -1, self.h * self.d_k)

        # Multiply by Wo
        # (batch, seq_len, d_model) --> (batch, seq_len, d_model)
        return self.w_o(x)

class EncoderBlock(nn.Module):

    def __init__(self, features: int, self_attention_block: MultiHeadAttentionBlock, feed_forward_block: FeedForwardBlock, dropout: float) -> None:
        super().__init__()
        self.self_attention_block = self_attention_block
        self.feed_forward_block = feed_forward_block
        self.residual_connections = nn.ModuleList([ResidualConnection(features, dropout) for _ in range(2)])

    def forward(self, x, src_mask):
        x = self.residual_connections[0](x, lambda x: self.self_attention_block(x, x, x, src_mask))
        x = self.residual_connections[1](x, self.feed_forward_block)
        return x

class Encoder(nn.Module):

    def __init__(self, features: int, layers: nn.ModuleList) -> None:
        super().__init__()
        self.layers = layers
        self.norm = LayerNormalization(features)

    def forward(self, x, mask):
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)

class DecoderBlock(nn.Module):

    def __init__(self, features: int, self_attention_block: MultiHeadAttentionBlock, cross_attention_block: MultiHeadAttentionBlock, feed_forward_block: FeedForwardBlock, dropout: float) -> None:
        super().__init__()
        self.self_attention_block = self_attention_block
        self.cross_attention_block = cross_attention_block
        self.feed_forward_block = feed_forward_block
        self.residual_connections = nn.ModuleList([ResidualConnection(features, dropout) for _ in range(3)])

    def forward(self, x, encoder_output, src_mask, tgt_mask):
        x = self.residual_connections[0](x, lambda x: self.self_attention_block(x, x, x, tgt_mask))
        x = self.residual_connections[1](x, lambda x: self.cross_attention_block(x, encoder_output, encoder_output, src_mask))
        x = self.residual_connections[2](x, self.feed_forward_block)
        return x

class Decoder(nn.Module):

    def __init__(self, features: int, layers: nn.ModuleList) -> None:
        super().__init__()
        self.layers = layers
        self.norm = LayerNormalization(features)

    def forward(self, x, encoder_output, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, encoder_output, src_mask, tgt_mask)
        return self.norm(x)

class ProjectionLayer(nn.Module):

    def __init__(self, d_model, vocab_size) -> None:
        super().__init__()
        self.proj = nn.Linear(d_model, vocab_size)

    def forward(self, x) -> None:
        # (batch, seq_len, d_model) --> (batch, seq_len, vocab_size)
        return self.proj(x)

class Transformer(nn.Module):

    def __init__(self, encoder: Encoder, decoder: Decoder, src_embed: InputEmbeddings, tgt_embed: InputEmbeddings, src_pos: PositionalEncoding, tgt_pos: PositionalEncoding, projection_layer: ProjectionLayer) -> None:
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.src_embed = src_embed
        self.tgt_embed = tgt_embed
        self.src_pos = src_pos
        self.tgt_pos = tgt_pos
        self.projection_layer = projection_layer

    def encode(self, src, src_mask):
        # (batch, seq_len, d_model)
        src = self.src_embed(src)
        src = self.src_pos(src)
        return self.encoder(src, src_mask)

    def decode(self, encoder_output: torch.Tensor, src_mask: torch.Tensor, tgt: torch.Tensor, tgt_mask: torch.Tensor):
        # (batch, seq_len, d_model)
        tgt = self.tgt_embed(tgt)
        tgt = self.tgt_pos(tgt)
        return self.decoder(tgt, encoder_output, src_mask, tgt_mask)

    def project(self, x):
        # (batch, seq_len, vocab_size)
        return self.projection_layer(x)

def build_transformer(src_vocab_size: int, tgt_vocab_size: int, src_seq_len: int, tgt_seq_len: int, d_model: int=512, N: int=6, h: int=8, dropout: float=0.1, d_ff: int=2048) -> Transformer:
    # Create the embedding layers
    src_embed = InputEmbeddings(d_model, src_vocab_size)
    tgt_embed = InputEmbeddings(d_model, tgt_vocab_size)

    # Create the positional encoding layers
    src_pos = PositionalEncoding(d_model, src_seq_len, dropout)
    tgt_pos = PositionalEncoding(d_model, tgt_seq_len, dropout)

    # Create the encoder blocks
    encoder_blocks = []
    for _ in range(N):
        encoder_self_attention_block = MultiHeadAttentionBlock(d_model, h, dropout)
        feed_forward_block = FeedForwardBlock(d_model, d_ff, dropout)
        encoder_block = EncoderBlock(d_model, encoder_self_attention_block, feed_forward_block, dropout)
        encoder_blocks.append(encoder_block)

    # Create the decoder blocks
    decoder_blocks = []
    for _ in range(N):
        decoder_self_attention_block = MultiHeadAttentionBlock(d_model, h, dropout)
        decoder_cross_attention_block = MultiHeadAttentionBlock(d_model, h, dropout)
        feed_forward_block = FeedForwardBlock(d_model, d_ff, dropout)
        decoder_block = DecoderBlock(d_model, decoder_self_attention_block, decoder_cross_attention_block, feed_forward_block, dropout)
        decoder_blocks.append(decoder_block)

    # Create the encoder and decoder
    encoder = Encoder(d_model, nn.ModuleList(encoder_blocks))
    decoder = Decoder(d_model, nn.ModuleList(decoder_blocks))

    # Create the projection layer
    projection_layer = ProjectionLayer(d_model, tgt_vocab_size)

    # Create the transformer
    transformer = Transformer(encoder, decoder, src_embed, tgt_embed, src_pos, tgt_pos, projection_layer)

    # Initialize the parameters
    for p in transformer.parameters():
        if p.dim() > 1:
            nn.init.xavier_uniform_(p)

    return transformer

# %% [markdown]
# # **Model Training**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from torchtext.vocab import build_vocab_from_iterator


# 1. DATA PREPROCESSING


# Load dataset
df_train = pd.read_csv("/content/spoc-train.csv")
df_train.dropna(inplace=True)

# Convert to list of tuples (pseudocode, code)
data_pairs = list(zip(df_train[' text'].tolist(), df_train['code'].tolist()))

# Tokenization function (character-wise, preserving spaces)
def tokenize_text(text):
    return list(text)

# Build vocabularies
special_tokens = ["<pad>", "<sos>", "<eos>"]
src_vocab = build_vocab_from_iterator((tokenize_text(pair[0]) for pair in data_pairs), specials=special_tokens)
tgt_vocab = build_vocab_from_iterator((tokenize_text(pair[1]) for pair in data_pairs), specials=special_tokens)

src_vocab.set_default_index(src_vocab["<pad>"])
tgt_vocab.set_default_index(tgt_vocab["<pad>"])

# 2. CUSTOM DATASET CLASS


class CodeDataset(Dataset):
    def __init__(self, data_pairs, src_vocab, tgt_vocab, src_max_len=200, tgt_max_len=200):
        self.data_pairs = data_pairs
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.src_max_len = src_max_len
        self.tgt_max_len = tgt_max_len

    def __len__(self):
        return len(self.data_pairs)

    def __getitem__(self, idx):
        src_text, tgt_text = self.data_pairs[idx]

        # Tokenize and convert to indices
        src_tokens = ["<sos>"] + tokenize_text(src_text) + ["<eos>"]
        tgt_tokens = ["<sos>"] + tokenize_text(tgt_text) + ["<eos>"]

        src_indices = [self.src_vocab[token] for token in src_tokens][:self.src_max_len]
        tgt_indices = [self.tgt_vocab[token] for token in tgt_tokens][:self.tgt_max_len]

        # Pad sequences
        src_indices += [self.src_vocab["<pad>"]] * (self.src_max_len - len(src_indices))
        tgt_indices += [self.tgt_vocab["<pad>"]] * ((self.tgt_max_len + 1) - len(tgt_indices))

        return torch.tensor(src_indices), torch.tensor(tgt_indices)

# Create dataset and dataloader
dataset = CodeDataset(data_pairs, src_vocab, tgt_vocab)
subset_size = 30000
batch_size = 32

train_subset = torch.utils.data.Subset(dataset, range(subset_size))
dataloader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)

if len(dataloader) == 0:
    print("🚨 ERROR: DataLoader is empty! Check dataset loading.")
    exit()

print(f"✅ DataLoader initialized with {len(dataloader)} batches.")


# 3. MODEL INITIALIZATION


class TransformerModel(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, N, h, dropout, d_ff):
        super().__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)

        self.positional_encoding = nn.Parameter(torch.zeros(1, 200, d_model))  # Fixed position embeddings

        self.transformer = nn.Transformer(
            d_model=d_model,
            nhead=h,
            num_encoder_layers=N,
            num_decoder_layers=N,
            dim_feedforward=d_ff,
            dropout=dropout,
            batch_first=True
        )

        self.fc_out = nn.Linear(d_model, tgt_vocab_size)

    def generate_square_subsequent_mask(self, size):
        """ Creates a lower-triangular mask for the decoder """
        mask = torch.triu(torch.ones(size, size), diagonal=1)
        return mask.masked_fill(mask == 1, float('-inf'))

    def forward(self, src, tgt):
        src_mask = None
        tgt_mask = self.generate_square_subsequent_mask(tgt.shape[1]).to(src.device)

        src_emb = self.encoder_embedding(src) + self.positional_encoding[:, :src.shape[1], :]
        tgt_emb = self.decoder_embedding(tgt) + self.positional_encoding[:, :tgt.shape[1], :]

        output = self.transformer(src_emb, tgt_emb, src_mask=src_mask, tgt_mask=tgt_mask)
        return self.fc_out(output)

# Model hyperparameters
d_model = 256
h = 8
N = 4
d_ff = 512
dropout = 0.1
src_vocab_size = len(src_vocab)
tgt_vocab_size = len(tgt_vocab)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Using device: {device}")

model = TransformerModel(src_vocab_size, tgt_vocab_size, d_model, N, h, dropout, d_ff).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss(ignore_index=src_vocab["<pad>"])
optimizer = optim.Adam(model.parameters(), lr=3e-4)


# 4. TRAINING FUNCTION


def train(model, dataloader, criterion, optimizer, num_epochs=10):
    model.train()
    print("🚀 Training Started...")

    for epoch in range(num_epochs):
        total_loss = 0
        print(f"\n🔵 Epoch {epoch+1}/{num_epochs}")

        for i, (src, tgt) in enumerate(dataloader):
            src, tgt = src.to(device), tgt.to(device)
            optimizer.zero_grad()
            print(f"🟡 Batch {i+1}/{len(dataloader)} - Src Shape: {src.shape}, Tgt Shape: {tgt.shape}")
            # Shift tgt by one position to the right
            tgt_input = tgt[:, :-1]
            tgt_output = tgt[:, 1:].contiguous().view(-1)

            output = model(src, tgt_input)
            output = output.view(-1, tgt_vocab_size)

            loss = criterion(output, tgt_output)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            total_loss += loss.item()

        print(f"✅ Epoch [{epoch+1}/{num_epochs}], Avg Loss: {total_loss/len(dataloader):.4f}")

    print("🎉 Training Complete!")

# Train the model
train(model, dataloader, criterion, optimizer, num_epochs=5)

# Save the model
torch.save(model.state_dict(), "transformer_model.pth")
print("✅ Model saved successfully!")
# Out:
# ✅ DataLoader initialized with 938 batches.
# ✅ Using device: cpu
# 🚀 Training Started...
#
# 🔵 Epoch 1/5
# 🟡 Batch 1/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 2/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 3/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 4/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 5/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 6/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 7/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 8/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 9/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 10/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 11/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 12/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 13/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 14/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 15/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 16/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 17/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 18/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 19/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 20/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 21/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 22/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 23/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 24/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 25/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 26/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 27/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 28/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 29/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 30/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 31/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 32/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 33/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 34/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 35/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 36/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 37/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 38/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 39/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 40/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 41/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 42/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 43/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 44/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 45/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 46/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 47/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 48/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 49/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 50/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 51/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 52/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 53/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 54/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 55/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 56/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 57/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 58/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 59/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 60/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 61/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 62/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 63/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 64/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 65/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 66/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 67/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 68/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 69/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 70/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 71/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 72/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 73/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 74/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 75/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 76/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 77/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 78/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 79/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 80/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 81/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 82/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 83/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 84/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 85/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 86/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 87/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 88/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 89/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 90/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 91/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 92/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 93/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 94/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 95/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 96/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 97/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 98/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 99/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 100/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 101/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 102/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 103/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 104/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 105/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 106/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 107/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 108/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 109/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 110/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 111/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 112/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 113/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 114/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 115/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 116/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 117/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 118/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 119/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 120/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 121/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 122/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 123/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 124/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 125/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 126/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 127/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 128/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 129/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 130/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 131/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 132/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 133/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 134/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 135/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 136/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 137/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 138/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 139/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 140/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 141/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 142/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 143/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 144/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 145/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 146/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 147/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 148/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 149/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 150/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 151/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 152/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 153/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 154/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 155/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 156/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 157/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 158/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 159/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 160/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 161/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 162/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 163/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 164/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 165/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 166/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 167/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 168/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 169/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 170/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 171/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 172/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 173/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 174/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 175/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 176/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 177/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 178/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 179/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 180/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 181/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 182/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 183/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 184/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 185/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 186/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 187/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 188/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 189/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 190/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 191/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 192/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 193/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 194/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 195/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 196/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 197/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 198/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 199/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 200/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 201/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 202/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 203/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 204/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 205/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 206/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 207/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 208/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 209/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 210/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 211/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 212/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 213/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 214/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 215/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 216/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 217/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 218/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 219/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 220/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 221/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 222/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 223/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 224/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 225/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 226/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 227/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 228/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 229/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 230/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 231/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 232/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 233/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 234/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 235/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 236/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 237/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 238/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 239/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 240/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 241/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 242/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 243/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 244/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 245/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 246/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 247/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 248/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 249/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 250/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 251/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 252/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 253/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 254/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 255/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 256/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 257/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 258/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 259/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 260/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 261/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 262/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 263/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 264/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 265/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 266/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 267/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 268/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 269/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 270/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 271/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 272/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 273/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 274/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 275/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 276/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 277/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 278/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 279/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 280/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 281/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 282/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 283/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 284/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 285/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 286/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 287/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 288/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 289/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 290/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 291/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 292/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 293/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 294/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 295/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 296/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 297/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 298/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 299/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 300/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 301/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 302/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 303/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 304/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 305/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 306/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 307/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 308/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 309/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 310/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 311/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 312/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 313/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 314/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 315/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 316/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 317/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 318/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 319/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 320/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 321/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 322/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 323/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 324/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 325/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 326/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 327/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 328/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 329/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 330/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 331/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 332/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 333/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 334/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 335/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 336/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 337/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 338/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 339/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 340/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 341/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 342/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 343/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 344/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 345/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 346/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 347/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 348/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 349/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 350/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 351/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 352/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 353/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 354/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 355/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 356/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 357/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 358/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 359/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 360/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 361/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 362/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 363/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 364/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 365/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 366/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 367/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 368/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 369/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 370/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 371/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 372/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 373/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 374/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 375/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 376/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 377/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 378/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 379/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 380/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 381/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 382/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 383/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 384/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 385/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 386/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 387/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 388/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 389/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 390/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 391/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 392/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 393/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 394/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 395/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 396/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 397/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 398/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 399/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 400/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 401/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 402/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 403/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 404/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 405/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 406/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 407/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 408/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 409/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 410/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 411/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 412/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 413/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 414/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 415/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 416/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 417/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 418/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 419/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 420/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 421/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 422/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 423/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 424/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 425/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 426/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 427/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 428/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 429/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 430/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 431/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 432/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 433/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 434/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 435/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 436/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 437/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 438/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 439/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 440/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 441/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 442/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 443/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 444/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 445/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 446/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 447/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 448/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 449/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 450/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 451/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 452/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 453/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 454/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 455/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 456/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 457/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 458/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 459/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 460/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 461/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 462/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 463/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 464/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 465/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 466/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 467/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 468/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 469/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 470/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 471/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 472/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 473/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 474/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 475/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 476/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 477/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 478/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 479/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 480/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 481/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 482/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 483/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 484/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 485/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 486/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 487/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 488/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 489/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 490/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 491/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 492/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 493/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 494/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 495/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 496/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 497/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 498/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 499/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 500/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 501/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 502/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 503/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 504/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 505/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 506/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 507/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 508/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 509/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 510/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 511/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 512/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 513/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 514/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 515/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 516/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 517/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 518/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 519/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 520/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 521/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 522/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 523/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 524/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 525/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 526/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 527/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 528/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 529/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 530/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 531/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 532/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 533/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 534/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 535/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 536/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 537/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 538/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 539/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 540/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 541/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 542/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 543/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 544/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 545/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 546/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 547/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 548/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 549/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 550/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 551/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 552/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 553/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 554/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 555/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 556/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 557/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 558/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 559/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 560/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 561/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 562/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 563/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 564/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# ...
# 🟡 Batch 752/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 753/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 754/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 755/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 756/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 757/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 758/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 759/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 760/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 761/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 762/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 763/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 764/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 765/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 766/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 767/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 768/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 769/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 770/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 771/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 772/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 773/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 774/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 775/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 776/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 777/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 778/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 779/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 780/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 781/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 782/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 783/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 784/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 785/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 786/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 787/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 788/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 789/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 790/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 791/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 792/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 793/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 794/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 795/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 796/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 797/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 798/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 799/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 800/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 801/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 802/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 803/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 804/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 805/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 806/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 807/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 808/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 809/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 810/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 811/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 812/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 813/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 814/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 815/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 816/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 817/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 818/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 819/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 820/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 821/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 822/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 823/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 824/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 825/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 826/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 827/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 828/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 829/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 830/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 831/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 832/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 833/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 834/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 835/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 836/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 837/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 838/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 839/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 840/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 841/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 842/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 843/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 844/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 845/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 846/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 847/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 848/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 849/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 850/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 851/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 852/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 853/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 854/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 855/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 856/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 857/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 858/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 859/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 860/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 861/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 862/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 863/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 864/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 865/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 866/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 867/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 868/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 869/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 870/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 871/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 872/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 873/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 874/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 875/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 876/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 877/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 878/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 879/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 880/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 881/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 882/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 883/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 884/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 885/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 886/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 887/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 888/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 889/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 890/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 891/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 892/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 893/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 894/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 895/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 896/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 897/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 898/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 899/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 900/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 901/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 902/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 903/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 904/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 905/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 906/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 907/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 908/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 909/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 910/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 911/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 912/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 913/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 914/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 915/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 916/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 917/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 918/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 919/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 920/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 921/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 922/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 923/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 924/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 925/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 926/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 927/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 928/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 929/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 930/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 931/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 932/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 933/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 934/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 935/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 936/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 937/938 - Src Shape: torch.Size([32, 200]), Tgt Shape: torch.Size([32, 201])
# 🟡 Batch 938/938 - Src Shape: torch.Size([16, 200]), Tgt Shape: torch.Size([16, 201])
# ✅ Epoch [5/5], Avg Loss: 0.3684
# 🎉 Training Complete!
# ✅ Model saved successfully!

# %% [markdown]
# # **Streamlit code for creating App.py**

# %%
# %%writefile app.py
import streamlit as st
import torch
import torch.nn as nn
from torchtext.vocab import build_vocab_from_iterator
import pandas as pd
import base64
from PIL import Image

# 1. COVER PAGE
image_path = "/content/PseudotoCppCover.jpg"
def get_base64(image_path):
    with open(image_path, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode()
base64_image = get_base64(image_path)
st.set_page_config(page_title="Pseudocode to C++ Converter", layout="centered")
st.markdown(
    f"""
    <style>
    [data-testid="stAppViewContainer"] {{
        background-image: url("data:image/jpeg;base64,{base64_image}");
        background-size: cover;
        background-position: center;
        background-repeat: no-repeat;
    }}
    [data-testid="stAppViewContainer"] {{
        color: rgb(0, 0, 0);  !important;
    }}
    </style>
    """,
    unsafe_allow_html=True
)


st.title("Pseudocode to C++ Code Generator")
st.write("Convert pseudocode into C++ code using a Transformer model.")


# 2. LOAD MODEL & VOCAB


def tokenize_text(text):
    return list(text)

# Load dataset (for vocab)
df_train = pd.read_csv("spoc-train.csv")
df_train.dropna(inplace=True)
data_pairs = list(zip(df_train[' text'].tolist(), df_train['code'].tolist()))

# Build vocabularies
special_tokens = ["<pad>", "<sos>", "<eos>"]
src_vocab = build_vocab_from_iterator((tokenize_text(pair[0]) for pair in data_pairs), specials=special_tokens)
tgt_vocab = build_vocab_from_iterator((tokenize_text(pair[1]) for pair in data_pairs), specials=special_tokens)

src_vocab.set_default_index(src_vocab["<pad>"])
tgt_vocab.set_default_index(tgt_vocab["<pad>"])
idx_to_tgt = {idx: token for token, idx in tgt_vocab.get_stoi().items()}

class TransformerModel(nn.Module):
    def __init__(self, src_vocab_size, tgt_vocab_size, d_model, N, h, dropout, d_ff):
        super().__init__()
        self.encoder_embedding = nn.Embedding(src_vocab_size, d_model)
        self.decoder_embedding = nn.Embedding(tgt_vocab_size, d_model)
        self.positional_encoding = nn.Parameter(torch.zeros(1, 200, d_model))
        self.transformer = nn.Transformer(
            d_model=d_model,
            nhead=h,
            num_encoder_layers=N,
            num_decoder_layers=N,
            dim_feedforward=d_ff,
            dropout=dropout,
            batch_first=True
        )
        self.fc_out = nn.Linear(d_model, tgt_vocab_size)

    def generate_square_subsequent_mask(self, size):
        mask = torch.triu(torch.ones(size, size), diagonal=1)
        return mask.masked_fill(mask == 1, float('-inf'))

    def forward(self, src, tgt):
        src_mask = None
        tgt_mask = self.generate_square_subsequent_mask(tgt.shape[1]).to(src.device)
        src_emb = self.encoder_embedding(src) + self.positional_encoding[:, :src.shape[1], :]
        tgt_emb = self.decoder_embedding(tgt) + self.positional_encoding[:, :tgt.shape[1], :]
        output = self.transformer(src_emb, tgt_emb, src_mask=src_mask, tgt_mask=tgt_mask)
        return self.fc_out(output)

# Load model
model = TransformerModel(len(src_vocab), len(tgt_vocab), 256, 4, 8, 0.1, 512)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.load_state_dict(torch.load("transformer_model.pth", map_location=device))
model.to(device)
model.eval()


# 3. TRANSLATION FUNCTION

def translate_pseudocode(pseudocode, max_length=200):
    model.eval()
    src_tokens = ["<sos>"] + tokenize_text(pseudocode) + ["<eos>"]
    src_indices = [src_vocab[token] for token in src_tokens] + [src_vocab["<pad>"]] * (max_length - len(src_tokens))
    src_tensor = torch.tensor([src_indices], device=device)
    tgt_indices = [tgt_vocab["<sos>"]]
    tgt_tensor = torch.tensor([tgt_indices], device=device)

    for _ in range(max_length):
        with torch.no_grad():
            output = model(src_tensor, tgt_tensor)
            next_token = output[:, -1, :].argmax(dim=-1).item()
        tgt_indices.append(next_token)
        if next_token == tgt_vocab["<eos>"]:
            break
        tgt_tensor = torch.tensor([tgt_indices], device=device)

    return "".join(idx_to_tgt[idx] for idx in tgt_indices[1:-1])


# 4. STREAMLIT UI


st.subheader("Convert Pseudocode to C++")
pseudocode_input = st.text_area("Enter Pseudocode:", "in the function gcd(a,b=integers)")
if st.button("Convert"):
    with st.spinner("Generating C++ Code..."):
        generated_code = translate_pseudocode(pseudocode_input)
    st.success("Generated C++ Code:")
    st.code(generated_code, language="cpp")
# Out:
# Overwriting app.py

# %% [markdown]
# # **Run and  copy the ouput address and then Paste in the url generated**

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.169.32.13

# %% [markdown]
# # **Run Streamlit App**

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠙⠹⠸
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.169.32.13:8501
#
# ⠼⠴your url is: https://hip-poets-shout.loca.lt
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py:1160: UserWarning: Converting mask without torch.bool dtype to bool; this will negatively affect performance. Prefer to use a boolean mask directly. (Triggered internally at ../aten/src/ATen/native/transformers/attention.cpp:150.)
#   return torch._native_multi_head_attention(
#   Stopping...
# ^C
